# %%
# Fast install with caching - only install what's needed
import subprocess
import sys
import os

# Use --no-cache-dir for faster installs (use cache if exists)
packages = [
    "torch", "transformers", "accelerate", "peft", 
    "trl", "bitsandbytes", "datasets"
]

# Install in single command with --no-cache-dir for speed
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "--upgrade", 
    "--no-cache-dir", *packages
])

# Install lighter dependencies
subprocess.check_call([
    sys.executable, "-m", "pip", "install", 
    "sentencepiece", "protobuf", "huggingface_hub"
])

print("✅ Dependencies installed in optimized mode!")

# %%
import os
import json
import torch
import gc
from datetime import datetime
from tqdm import tqdm

# Transformers
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline
)

# PEFT for LoRA
from peft import (
    LoraConfig,
    get_peft_model,
    prepare_model_for_kbit_training,
    PeftModel,
    PeftConfig
)

# TRL for SFT
from trl import SFTTrainer, DataCollatorForCompletionOnlyLM

# Datasets
from datasets import Dataset, load_dataset

# Utilities
import torch.nn.functional as F
from huggingface_hub import login

print("✅ All imports loaded!")
