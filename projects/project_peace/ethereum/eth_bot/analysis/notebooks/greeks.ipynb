# %%
import sqlite3
from pathlib import Path

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
ROOT = Path.cwd().parents[1]

DB_PATH = ROOT / "storage" / "database" / "ETH.db"

conn = sqlite3.connect(DB_PATH)

print(DB_PATH)
# Out:
# d:\Projects\myprojets\projects\project_peace\ethereum\eth_bot\storage\database\ETH.db

# %%
query = """
SELECT *
FROM greeks
ORDER BY instrument_name
"""

df = pd.read_sql(query, conn)

df.head()
# Out:
#    id exchange     instrument_name    delta    gamma    theta     vega  \
# 0   1  Deribit  ETH-14AUG26-1600-C  0.92943  0.00055 -1.04851  0.54083
# 1   2  Deribit  ETH-14AUG26-1600-P -0.07057  0.00055 -1.04851  0.54083
# 2   3  Deribit  ETH-14AUG26-1700-C  0.85898  0.00098 -1.59880  0.89536
# 3   4  Deribit  ETH-14AUG26-1700-P -0.14097  0.00098 -1.59846  0.89517
# 4   5  Deribit  ETH-14AUG26-1750-C  0.80461  0.00126 -1.90205  1.10502
#
#        rho  mark_iv  bid_iv  ask_iv  underlying_price           created_at
# 0  0.63463    61.67    0.00   83.62           1917.72  2026-07-29 10:19:20
# 1 -0.06251    61.67   60.81   62.24           1917.72  2026-07-29 10:19:20
# 2  0.61536    56.80   39.46   72.08           1917.72  2026-07-29 10:19:20
# 3 -0.12531    56.80   55.72   57.86           1917.77  2026-07-29 10:19:21
# 4  0.58830    54.75   43.31   66.92           1917.77  2026-07-29 10:19:21

# %%
print(df.shape)

df.info()
# Out:
# (100, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                100 non-null    int64
#  1   exchange          100 non-null    object
#  2   instrument_name   100 non-null    object
#  3   delta             100 non-null    float64
#  4   gamma             100 non-null    float64
#  5   theta             100 non-null    float64
#  6   vega              100 non-null    float64
#  7   rho               100 non-null    float64
#  8   mark_iv           100 non-null    float64
#  9   bid_iv            100 non-null    float64
#  10  ask_iv            100 non-null    float64
#  11  underlying_price  100 non-null    float64
#  12  created_at        100 non-null    object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 10.3+ KB
