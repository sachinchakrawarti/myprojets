# %%
import sqlite3
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
ROOT = Path.cwd().parents[1]

DB = ROOT / "storage" / "database" / "ETH.db"

conn = sqlite3.connect(DB)

# %%
df = pd.read_sql(
    "SELECT * FROM implied_volatility",
    conn
)

df.head()
# Out:
#    id exchange     instrument_name option_type  strike  expiration_timestamp  \
# 0   1  Deribit  ETH-30JUL26-1600-C        call  1600.0         1785398400000
# 1   2  Deribit  ETH-30JUL26-1600-P         put  1600.0         1785398400000
# 2   3  Deribit  ETH-30JUL26-1700-C        call  1700.0         1785398400000
# 3   4  Deribit  ETH-30JUL26-1700-P         put  1700.0         1785398400000
# 4   5  Deribit  ETH-30JUL26-1750-C        call  1750.0         1785398400000
#
#    expiration_datetime  mark_iv  bid_iv  ask_iv  underlying_price  \
# 0  2026-07-30 08:00:00   109.27     0.0  319.95           1916.81
# 1  2026-07-30 08:00:00   109.27     0.0  141.11           1916.81
# 2  2026-07-30 08:00:00    91.92     0.0  250.38           1916.81
# 3  2026-07-30 08:00:00    91.92     0.0   97.84           1916.81
# 4  2026-07-30 08:00:00    86.93     0.0  213.73           1916.81
#
#             created_at
# 0  2026-07-29 10:24:30
# 1  2026-07-29 10:24:31
# 2  2026-07-29 10:24:31
# ...
