# %%
import sqlite3
from pathlib import Path

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
ROOT = Path.cwd().parents[1]

DB_PATH = ROOT / "storage" / "database" / "ETH.db"

conn = sqlite3.connect(DB_PATH)

print(DB_PATH)
# Out:
# d:\Projects\myprojets\projects\project_peace\ethereum\eth_bot\storage\database\ETH.db

# %%
query = """
SELECT *
FROM option_chain
ORDER BY expiration_timestamp, strike
"""

df = pd.read_sql(query, conn)

df.head()
# Out:
#     id exchange     instrument_name base_currency option_type  strike  \
# 0  719  Deribit  ETH-30JUL26-1600-C           ETH        call  1600.0
# 1  720  Deribit  ETH-30JUL26-1600-P           ETH         put  1600.0
# 2  721  Deribit  ETH-30JUL26-1700-C           ETH        call  1700.0
# 3  722  Deribit  ETH-30JUL26-1700-P           ETH         put  1700.0
# 4  723  Deribit  ETH-30JUL26-1750-C           ETH        call  1750.0
#
#    expiration_timestamp  expiration_datetime bid_price ask_price mark_price  \
# 0         1785398400000  2026-07-30 08:00:00      None      None       None
# 1         1785398400000  2026-07-30 08:00:00      None      None       None
# 2         1785398400000  2026-07-30 08:00:00      None      None       None
# 3         1785398400000  2026-07-30 08:00:00      None      None       None
# 4         1785398400000  2026-07-30 08:00:00      None      None       None
#
#   last_price open_interest volume underlying_price           created_at
# 0       None          None   None             None  2026-07-29 10:09:53
# 1       None          None   None             None  2026-07-29 10:09:53
# 2       None          None   None             None  2026-07-29 10:09:53
# 3       None          None   None             None  2026-07-29 10:09:53
# 4       None          None   None             None  2026-07-29 10:09:53

# %%
print(df.shape)

df.info()
# Out:
# (718, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    718 non-null    int64
#  1   exchange              718 non-null    object
#  2   instrument_name       718 non-null    object
#  3   base_currency         718 non-null    object
#  4   option_type           718 non-null    object
#  5   strike                718 non-null    float64
#  6   expiration_timestamp  718 non-null    int64
#  7   expiration_datetime   718 non-null    object
#  8   bid_price             0 non-null      object
#  9   ask_price             0 non-null      object
#  10  mark_price            0 non-null      object
#  11  last_price            0 non-null      object
#  12  open_interest         0 non-null      object
#  13  volume                0 non-null      object
#  14  underlying_price      0 non-null      object
#  15  created_at            718 non-null    object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 89.9+ KB
